# %%
from init import readFile
FILE = 'Samples\\temperature_sample_calibrate.csv'
time, temperature = readFile(FILE)

# %%
from init import initPopulation

population = initPopulation(25)

# %%
from fit import fit, stopAfter
from init import BORNE_A, BORNE_B, BORNE_C
import numpy as np

best, best_fitness, duration = fit(population, time, temperature, nb_of_cycle=200, stopFunction=stopAfter(100), number_of_parents=10, alpha_a_crossover=.2, number_of_bc_flips=4, number_of_resets=10, number_of_a_variations=10, a_std_mutation=.1, borne_a=BORNE_A, borne_b=[1, 35], borne_c=BORNE_C, abs_error=.1)
# Out:
#  52% (104 of 200) |###########           | Elapsed Time: 0:00:01 ETA:   0:00:01
# best fitness : 0.011522294144597966
# best individual : [ 0.15 33.    2.  ]
# durations : 1.445998191833496

# %%
from individu import temperatureCalculIndividu as temperatureCalc
from population import total_fitness

real_temperature = np.array([temperatureCalc(i, .16, 33, 5) for i in time])
real_fitness = total_fitness(np.array(best), time, real_temperature)

# %%
import matplotlib.pyplot as plt
plt.plot(best_fitness, c="red")
plt.plot(real_fitness)
